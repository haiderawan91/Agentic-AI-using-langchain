# %%
from  langchain_openai import ChatOpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from  langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
# Out:
# Bro API KEY Variable exists

# %% [markdown]
# # **CHAIN WITH CUSTOM RUNNABLE**

# %%
# TASK -1 [Prompt]

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{input}")])

# %%
# TASK - 2 [LLM]

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)

# %%
# TASK - 3 [Str Parser]

str_parser = StrOutputParser()

# %%
# TASK - 4 [Custom Runnable]
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str)-> dict:

    return {"text" : text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
# TASK - 5 [Template For Post]

prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "You're a social media post generator. "),
        ("human", "Create a post for the following text for LinkedIn: {text}"),
    ]
)

# %%
# TASK - 6 [Generate the Post]

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)

# %%
# TASK - 7 [Str Parser]

str_parser = StrOutputParser()

# %%
# CHAIN

chain = prompt_template | llm_openai | str_parser | dictionary_maker_runnable | prompt_post | llm_openai | str_parser

chain.invoke("What is the capital of France?")
# Out:
# 'Quick geography refresher: the capital of France is Paris — and it’s more than a landmark-filled city; it’s a global hub for culture, innovation and business. Whether you’re considering market entry, recruiting international talent, or planning to attend events like VivaTech, Paris often plays a strategic role. What cities are on your global strategy radar this year?\n\n#Paris #France #InternationalBusiness #GlobalStrategy #BusinessTravel'
